# %% [markdown]
# # Bonus Unit 1: Let's train Huggy the Dog 🐶 to fetch a stick

# %% [markdown]
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/unit2/thumbnail.png" alt="Bonus Unit 1Thumbnail">
#
# In this notebook, we'll reinforce what we learned in the first Unit by **teaching Huggy the Dog to fetch the stick and then play with it directly in your browser**
#
# ⬇️ Here is an example of what **you will achieve at the end of the unit.** ⬇️ (launch ▶ to see)

# %%
# %%html
# <video controls autoplay><source src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/unit-bonus1/huggy.mp4" type="video/mp4"></video>
# Out:
# <video controls autoplay><source src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/unit-bonus1/huggy.mp4" type="video/mp4"></video>

# %% [markdown]
# ### The environment 🎮
#
# - Huggy the Dog, an environment created by [Thomas Simonini](https://twitter.com/ThomasSimonini) based on [Puppo The Corgi](https://blog.unity.com/technology/puppo-the-corgi-cuteness-overload-with-the-unity-ml-agents-toolkit)
#
# ### The library used 📚
#
# - [MLAgents (Hugging Face version)](https://github.com/huggingface/ml-agents)

# %% [markdown]
# We're constantly trying to improve our tutorials, so **if you find some issues in this notebook**, please [open an issue on the Github Repo](https://github.com/huggingface/deep-rl-class/issues).

# %% [markdown]
# ## Objectives of this notebook 🏆
#
# At the end of the notebook, you will:
#
# - Understand **the state space, action space and reward function used to train Huggy**.
# - **Train your own Huggy** to fetch the stick.
# - Be able to play **with your trained Huggy directly in your browser**.

# %% [markdown]
# ## This notebook is from Deep Reinforcement Learning Course
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/deep-rl-course-illustration.jpg" alt="Deep RL Course illustration"/>

# %% [markdown]
# ## Prerequisites 🏗️
#
# Before diving into the notebook, you need to:
#
# 🔲 📚 **Develop an understanding of the foundations of Reinforcement learning** (MC, TD, Rewards hypothesis...) by doing Unit 1
#
# 🔲 📚 **Read the introduction to Huggy** by doing Bonus Unit 1

# %% [markdown]
# ## Set the GPU 💪
# - To **accelerate the agent's training, we'll use a GPU**. To do that, go to `Runtime > Change Runtime type`
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/gpu-step1.jpg" alt="GPU Step 1">

# %% [markdown]
# - `Hardware Accelerator > GPU`
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/gpu-step2.jpg" alt="GPU Step 2">

# %% [markdown]
# ## Clone the repository and install the dependencies 🔽
#
# - We need to clone the repository, that **contains the experimental version of the library that allows you to push your trained agent to the Hub.**

# %%
# %%capture
# Clone this specific repository (can take 3min)
# !git clone https://github.com/huggingface/ml-agents/

# %%
# %%capture
# Go inside the repository and install the package (can take 3min)
# %cd ml-agents
# !pip3 install -e ./ml-agents-envs
# !pip3 install -e ./ml-agents

# %% [markdown]
# ## Download and move the environment zip file in `./trained-envs-executables/linux/`
#
# - Our environment executable is in a zip file.
# - We need to download it and place it to `./trained-envs-executables/linux/`

# %%
# !mkdir ./trained-envs-executables
# !mkdir ./trained-envs-executables/linux

# %%
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1zv3M95ZJTWHUVOWT6ckq_cm98nft8gdF' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1zv3M95ZJTWHUVOWT6ckq_cm98nft8gdF" -O ./trained-envs-executables/linux/Huggy.zip && rm -rf /tmp/cookies.txt
# Out:
# --2023-01-11 16:36:09--  https://docs.google.com/uc?export=download&confirm=t&id=1zv3M95ZJTWHUVOWT6ckq_cm98nft8gdF
# Resolving docs.google.com (docs.google.com)... 142.250.145.139, 142.250.145.138, 142.250.145.101, ...
# Connecting to docs.google.com (docs.google.com)|142.250.145.139|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-0k-28-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/pll1k8809jnj2p8uaj5um7oblfq0d5q0/1673454900000/15803371278684422230/*/1zv3M95ZJTWHUVOWT6ckq_cm98nft8gdF?e=download&uuid=2d3111bd-1730-4325-bb33-8cf2e15c6259 [following]
# Warning: wildcards not supported in HTTP.
# --2023-01-11 16:36:09--  https://doc-0k-28-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/pll1k8809jnj2p8uaj5um7oblfq0d5q0/1673454900000/15803371278684422230/*/1zv3M95ZJTWHUVOWT6ckq_cm98nft8gdF?e=download&uuid=2d3111bd-1730-4325-bb33-8cf2e15c6259
# Resolving doc-0k-28-docs.googleusercontent.com (doc-0k-28-docs.googleusercontent.com)... 108.177.96.132, 2a00:1450:4013:c06::84
# Connecting to doc-0k-28-docs.googleusercontent.com (doc-0k-28-docs.googleusercontent.com)|108.177.96.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 39214997 (37M) [application/x-zip-compressed]
# Saving to: ‘./trained-envs-executables/linux/Huggy.zip’
#
# ./trained-envs-exec 100%[===================>]  37.40M   194MB/s    in 0.2s
#
# 2023-01-11 16:36:10 (194 MB/s) - ‘./trained-envs-executables/linux/Huggy.zip’ saved [39214997/39214997]

# %% [markdown]
# Download the file Huggy.zip from https://drive.google.com/uc?export=download&id=1zv3M95ZJTWHUVOWT6ckq_cm98nft8gdF using `wget`. Check out the full solution to download large files from GDrive [here](https://bcrf.biochem.wisc.edu/2021/02/05/download-google-drive-files-using-wget/)

# %%
# %%capture
# !unzip -d ./trained-envs-executables/linux/ ./trained-envs-executables/linux/Huggy.zip

# %% [markdown]
# Make sure your file is accessible

# %%
# !chmod -R 755 ./trained-envs-executables/linux/Huggy

# %% [markdown]
# ## Let's recap how this environment works
#
# ### The State Space: what Huggy "perceives."
#
# Huggy doesn't "see" his environment. Instead, we provide him information about the environment:
#
# - The target (stick) position
# - The relative position between himself and the target
# - The orientation of his legs.
#
# Given all this information, Huggy **can decide which action to take next to fulfill his goal**.
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/unit-bonus1/huggy.jpg" alt="Huggy" width="100%">
#
#
# ### The Action Space: what moves Huggy can do
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/unit-bonus1/huggy-action.jpg" alt="Huggy action" width="100%">
#
# **Joint motors drive huggy legs**. It means that to get the target, Huggy needs to **learn to rotate the joint motors of each of his legs correctly so he can move**.
#
# ### The Reward Function
#
# The reward function is designed so that **Huggy will fulfill his goal** : fetch the stick.
#
# Remember that one of the foundations of Reinforcement Learning is the *reward hypothesis*: a goal can be described as the **maximization of the expected cumulative reward**.
#
# Here, our goal is that Huggy **goes towards the stick but without spinning too much**. Hence, our reward function must translate this goal.
#
# Our reward function:
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/unit-bonus1/reward.jpg" alt="Huggy reward function" width="100%">
#
# - *Orientation bonus*: we **reward him for getting close to the target**.
# - *Time penalty*: a fixed-time penalty given at every action to **force him to get to the stick as fast as possible**.
# - *Rotation penalty*: we penalize Huggy if **he spins too much and turns too quickly**.
# - *Getting to the target reward*: we reward Huggy for **reaching the target**.

# %% [markdown]
# ## Check the Huggy config file
#
# - In ML-Agents, you define the **training hyperparameters into config.yaml files.**
#
# - For the scope of this notebook, we're not going to modify the hyperparameters, but if you want to try as an experiment, you should also try to modify some other hyperparameters, Unity provides very [good documentation explaining each of them here](https://github.com/Unity-Technologies/ml-agents/blob/main/docs/Training-Configuration-File.md).

# %% [markdown]
# - **In the case you want to modify the hyperparameters**, in Google Colab notebook, you can click here to open the config.yaml: `/content/ml-agents/config/ppo/Huggy.yaml`
#
# - For instance **if you want to save more models during the training** (for now, we save every 200,000 training timesteps). You need to modify:
#   - `checkpoint_interval`: The number of training timesteps collected between each checkpoint.
#   - `keep_checkpoints`: The maximum number of model checkpoints to keep.
#
# => Just keep in mind that **decreasing the `checkpoint_interval` means more models to upload to the Hub and so a longer uploading time**
# We’re now ready to train our agent 🔥.

# %% [markdown]
# ## Train our agent
#
# To train our agent, we just need to **launch mlagents-learn and select the executable containing the environment.**
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/unit-bonus1/mllearn.png" alt="ml learn function" width="100%">
#
# With ML Agents, we run a training script. We define four parameters:
#
# 1. `mlagents-learn <config>`: the path where the hyperparameter config file is.
# 2. `--env`: where the environment executable is.
# 3. `--run_id`: the name you want to give to your training run id.
# 4. `--no-graphics`: to not launch the visualization during the training.
#
# Train the model and use the `--resume` flag to continue training in case of interruption.
#
# > It will fail first time when you use `--resume`, try running the block again to bypass the error.

# %% [markdown]
# The training will take 30 to 45min depending on your machine (don't forget to **set up a GPU**), go take a ☕️you deserve it 🤗.

# %%
# !mlagents-learn ./config/ppo/Huggy.yaml --env=./trained-envs-executables/linux/Huggy/Huggy --run-id="Huggy" --no-graphics
# Out:
#             ┐  ╖
#         ╓╖╬│╡  ││╬╖╖
#     ╓╖╬│││││┘  ╬│││││╬╖
#  ╖╬│││││╬╜        ╙╬│││││╖╖                               ╗╗╗
#  ╬╬╬╬╖││╦╖        ╖╬││╗╣╣╣╬      ╟╣╣╬    ╟╣╣╣             ╜╜╜  ╟╣╣
#  ╬╬╬╬╬╬╬╬╖│╬╖╖╓╬╪│╓╣╣╣╣╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╒╣╣╖╗╣╣╣╗   ╣╣╣ ╣╣╣╣╣╣ ╟╣╣╖   ╣╣╣
#  ╬╬╬╬┐  ╙╬╬╬╬│╓╣╣╣╝╜  ╫╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╟╣╣╣╙ ╙╣╣╣  ╣╣╣ ╙╟╣╣╜╙  ╫╣╣  ╟╣╣
#  ╬╬╬╬┐     ╙╬╬╣╣      ╫╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╟╣╣╬   ╣╣╣  ╣╣╣  ╟╣╣     ╣╣╣┌╣╣╜
#  ╬╬╬╜       ╬╬╣╣      ╙╝╣╣╬      ╙╣╣╣╗╖╓╗╣╣╣╜ ╟╣╣╬   ╣╣╣  ╣╣╣  ╟╣╣╦╓    ╣╣╣╣╣
#  ╙   ╓╦╖    ╬╬╣╣   ╓╗╗╖            ╙╝╣╣╣╣╝╜   ╘╝╝╜   ╝╝╝  ╝╝╝   ╙╣╣╣    ╟╣╣╣
#    ╩╬╬╬╬╬╬╦╦╬╬╣╣╗╣╣╣╣╣╣╣╝                                             ╫╣╣╣╣
#       ╙╬╬╬╬╬╬╬╣╣╣╣╣╣╝╜
#           ╙╬╬╬╣╣╣╜
#              ╙
#
#  Version information:
#   ml-agents: 0.29.0.dev0,
#   ml-agents-envs: 0.29.0.dev0,
#   Communicator API: 1.5.0,
#   PyTorch: 1.8.1+cu102
# [INFO] Connected to Unity environment with package version 2.2.1-exp.1 and communication version 1.5.0
# [INFO] Connected new brain: Huggy?team=0
# [INFO] Hyperparameters for behavior name Huggy:
# 	trainer_type:	ppo
# 	hyperparameters:
# 	  batch_size:	2048
# 	  buffer_size:	20480
# 	  learning_rate:	0.0003
# 	  beta:	0.005
# 	  epsilon:	0.2
# 	  lambd:	0.95
# 	  num_epoch:	3
# 	  learning_rate_schedule:	linear
# 	  beta_schedule:	linear
# 	  epsilon_schedule:	linear
# 	network_settings:
# 	  normalize:	True
# 	  hidden_units:	512
# 	  num_layers:	3
# 	  vis_encode_type:	simple
# 	  memory:	None
# 	  goal_conditioning_type:	hyper
# 	  deterministic:	False
# 	reward_signals:
# 	  extrinsic:
# 	    gamma:	0.995
# 	    strength:	1.0
# 	    network_settings:
# 	      normalize:	False
# 	      hidden_units:	128
# 	      num_layers:	2
# 	      vis_encode_type:	simple
# 	      memory:	None
# 	      goal_conditioning_type:	hyper
# 	      deterministic:	False
# 	init_path:	None
# 	keep_checkpoints:	15
# 	checkpoint_interval:	200000
# 	max_steps:	2000000
# 	time_horizon:	1000
# 	summary_freq:	50000
# 	threaded:	False
# 	self_play:	None
# 	behavioral_cloning:	None
# INFO:mlagents.trainers.stats:Hyperparameters for behavior name Huggy:
# 	trainer_type:	ppo
# 	hyperparameters:
# 	  batch_size:	2048
# 	  buffer_size:	20480
# 	  learning_rate:	0.0003
# 	  beta:	0.005
# 	  epsilon:	0.2
# 	  lambd:	0.95
# 	  num_epoch:	3
# 	  learning_rate_schedule:	linear
# 	  beta_schedule:	linear
# 	  epsilon_schedule:	linear
# 	network_settings:
# 	  normalize:	True
# 	  hidden_units:	512
# 	  num_layers:	3
# 	  vis_encode_type:	simple
# 	  memory:	None
# 	  goal_conditioning_type:	hyper
# 	  deterministic:	False
# 	reward_signals:
# 	  extrinsic:
# 	    gamma:	0.995
# 	    strength:	1.0
# 	    network_settings:
# 	      normalize:	False
# 	      hidden_units:	128
# 	      num_layers:	2
# 	      vis_encode_type:	simple
# 	      memory:	None
# 	      goal_conditioning_type:	hyper
# 	      deterministic:	False
# 	init_path:	None
# 	keep_checkpoints:	15
# 	checkpoint_interval:	200000
# 	max_steps:	2000000
# 	time_horizon:	1000
# 	summary_freq:	50000
# 	threaded:	False
# 	self_play:	None
# 	behavioral_cloning:	None
# [INFO] Huggy. Step: 50000. Time Elapsed: 66.709 s. Mean Reward: 1.703. Std of Reward: 0.898. Training.
# INFO:mlagents.trainers.stats:Huggy. Step: 50000. Time Elapsed: 66.709 s. Mean Reward: 1.703. Std of Reward: 0.898. Training.
# [INFO] Huggy. Step: 100000. Time Elapsed: 121.250 s. Mean Reward: 2.552. Std of Reward: 1.031. Training.
# INFO:mlagents.trainers.stats:Huggy. Step: 100000. Time Elapsed: 121.250 s. Mean Reward: 2.552. Std of Reward: 1.031. Training.
# [INFO] Huggy. Step: 150000. Time Elapsed: 177.653 s. Mean Reward: 3.051. Std of Reward: 1.171. Training.
# INFO:mlagents.trainers.stats:Huggy. Step: 150000. Time Elapsed: 177.653 s. Mean Reward: 3.051. Std of Reward: 1.171. Training.
# [INFO] Huggy. Step: 200000. Time Elapsed: 231.088 s. Mean Reward: 3.079. Std of Reward: 1.238. Training.
# INFO:mlagents.trainers.stats:Huggy. Step: 200000. Time Elapsed: 231.088 s. Mean Reward: 3.079. Std of Reward: 1.238. Training.
# [INFO] Exported results/Huggy/Huggy/Huggy-199674.onnx
# INFO:mlagents.trainers.torch.model_serialization:Exported results/Huggy/Huggy/Huggy-199674.onnx
# [INFO] Huggy. Step: 250000. Time Elapsed: 289.647 s. Mean Reward: 3.561. Std of Reward: 1.365. Training.
# INFO:mlagents.trainers.stats:Huggy. Step: 250000. Time Elapsed: 289.647 s. Mean Reward: 3.561. Std of Reward: 1.365. Training.
# [INFO] Huggy. Step: 300000. Time Elapsed: 345.160 s. Mean Reward: 3.634. Std of Reward: 1.529. Training.
# INFO:mlagents.trainers.stats:Huggy. Step: 300000. Time Elapsed: 345.160 s. Mean Reward: 3.634. Std of Reward: 1.529. Training.
# [INFO] Huggy. Step: 350000. Time Elapsed: 400.670 s. Mean Reward: 3.627. Std of Reward: 1.548. Training.
# INFO:mlagents.trainers.stats:Huggy. Step: 350000. Time Elapsed: 400.670 s. Mean Reward: 3.627. Std of Reward: 1.548. Training.
# [INFO] Huggy. Step: 400000. Time Elapsed: 460.331 s. Mean Reward: 3.436. Std of Reward: 1.720. Training.
# INFO:mlagents.trainers.stats:Huggy. Step: 400000. Time Elapsed: 460.331 s. Mean Reward: 3.436. Std of Reward: 1.720. Training.
# [INFO] Exported results/Huggy/Huggy/Huggy-399982.onnx
# INFO:mlagents.trainers.torch.model_serialization:Exported results/Huggy/Huggy/Huggy-399982.onnx
# [INFO] Huggy. Step: 450000. Time Elapsed: 514.611 s. Mean Reward: 3.803. Std of Reward: 1.650. Training.
# INFO:mlagents.trainers.stats:Huggy. Step: 450000. Time Elapsed: 514.611 s. Mean Reward: 3.803. Std of Reward: 1.650. Training.
# [INFO] Huggy. Step: 500000. Time Elapsed: 572.848 s. Mean Reward: 3.762. Std of Reward: 1.596. Training.
# INFO:mlagents.trainers.stats:Huggy. Step: 500000. Time Elapsed: 572.848 s. Mean Reward: 3.762. Std of Reward: 1.596. Training.
# [INFO] Huggy. Step: 550000. Time Elapsed: 628.685 s. Mean Reward: 3.730. Std of Reward: 1.578. Training.
# INFO:mlagents.trainers.stats:Huggy. Step: 550000. Time Elapsed: 628.685 s. Mean Reward: 3.730. Std of Reward: 1.578. Training.
# [INFO] Huggy. Step: 600000. Time Elapsed: 686.572 s. Mean Reward: 3.673. Std of Reward: 1.596. Training.
# INFO:mlagents.trainers.stats:Huggy. Step: 600000. Time Elapsed: 686.572 s. Mean Reward: 3.673. Std of Reward: 1.596. Training.
# [INFO] Exported results/Huggy/Huggy/Huggy-599775.onnx
# INFO:mlagents.trainers.torch.model_serialization:Exported results/Huggy/Huggy/Huggy-599775.onnx
# [INFO] Huggy. Step: 650000. Time Elapsed: 743.696 s. Mean Reward: 3.949. Std of Reward: 1.582. Training.
# INFO:mlagents.trainers.stats:Huggy. Step: 650000. Time Elapsed: 743.696 s. Mean Reward: 3.949. Std of Reward: 1.582. Training.
# [INFO] Huggy. Step: 700000. Time Elapsed: 803.824 s. Mean Reward: 3.722. Std of Reward: 1.673. Training.
# INFO:mlagents.trainers.stats:Huggy. Step: 700000. Time Elapsed: 803.824 s. Mean Reward: 3.722. Std of Reward: 1.673. Training.
# [INFO] Huggy. Step: 750000. Time Elapsed: 863.589 s. Mean Reward: 3.801. Std of Reward: 1.805. Training.
# INFO:mlagents.trainers.stats:Huggy. Step: 750000. Time Elapsed: 863.589 s. Mean Reward: 3.801. Std of Reward: 1.805. Training.
# [INFO] Huggy. Step: 800000. Time Elapsed: 920.593 s. Mean Reward: 3.839. Std of Reward: 1.820. Training.
# INFO:mlagents.trainers.stats:Huggy. Step: 800000. Time Elapsed: 920.593 s. Mean Reward: 3.839. Std of Reward: 1.820. Training.
# [INFO] Exported results/Huggy/Huggy/Huggy-799953.onnx
# INFO:mlagents.trainers.torch.model_serialization:Exported results/Huggy/Huggy/Huggy-799953.onnx
# [INFO] Huggy. Step: 850000. Time Elapsed: 980.902 s. Mean Reward: 3.821. Std of Reward: 1.956. Training.
# INFO:mlagents.trainers.stats:Huggy. Step: 850000. Time Elapsed: 980.902 s. Mean Reward: 3.821. Std of Reward: 1.956. Training.
# [INFO] Huggy. Step: 900000. Time Elapsed: 1037.966 s. Mean Reward: 3.627. Std of Reward: 1.855. Training.
# INFO:mlagents.trainers.stats:Huggy. Step: 900000. Time Elapsed: 1037.966 s. Mean Reward: 3.627. Std of Reward: 1.855. Training.
# [INFO] Huggy. Step: 950000. Time Elapsed: 1097.240 s. Mean Reward: 3.709. Std of Reward: 1.929. Training.
# INFO:mlagents.trainers.stats:Huggy. Step: 950000. Time Elapsed: 1097.240 s. Mean Reward: 3.709. Std of Reward: 1.929. Training.
# [INFO] Huggy. Step: 1000000. Time Elapsed: 1156.966 s. Mean Reward: 3.780. Std of Reward: 2.026. Training.
# INFO:mlagents.trainers.stats:Huggy. Step: 1000000. Time Elapsed: 1156.966 s. Mean Reward: 3.780. Std of Reward: 2.026. Training.
# [INFO] Exported results/Huggy/Huggy/Huggy-999930.onnx
# INFO:mlagents.trainers.torch.model_serialization:Exported results/Huggy/Huggy/Huggy-999930.onnx
# [INFO] Huggy. Step: 1050000. Time Elapsed: 1214.703 s. Mean Reward: 3.761. Std of Reward: 2.065. Training.
# INFO:mlagents.trainers.stats:Huggy. Step: 1050000. Time Elapsed: 1214.703 s. Mean Reward: 3.761. Std of Reward: 2.065. Training.
# [INFO] Huggy. Step: 1100000. Time Elapsed: 1274.356 s. Mean Reward: 3.620. Std of Reward: 1.920. Training.
# INFO:mlagents.trainers.stats:Huggy. Step: 1100000. Time Elapsed: 1274.356 s. Mean Reward: 3.620. Std of Reward: 1.920. Training.
# [INFO] Huggy. Step: 1150000. Time Elapsed: 1331.555 s. Mean Reward: 3.729. Std of Reward: 1.959. Training.
# INFO:mlagents.trainers.stats:Huggy. Step: 1150000. Time Elapsed: 1331.555 s. Mean Reward: 3.729. Std of Reward: 1.959. Training.
# [INFO] Huggy. Step: 1200000. Time Elapsed: 1393.139 s. Mean Reward: 3.802. Std of Reward: 1.876. Training.
# INFO:mlagents.trainers.stats:Huggy. Step: 1200000. Time Elapsed: 1393.139 s. Mean Reward: 3.802. Std of Reward: 1.876. Training.
# [INFO] Exported results/Huggy/Huggy/Huggy-1199792.onnx
# INFO:mlagents.trainers.torch.model_serialization:Exported results/Huggy/Huggy/Huggy-1199792.onnx
# [INFO] Huggy. Step: 1250000. Time Elapsed: 1450.634 s. Mean Reward: 3.689. Std of Reward: 2.002. Training.
# INFO:mlagents.trainers.stats:Huggy. Step: 1250000. Time Elapsed: 1450.634 s. Mean Reward: 3.689. Std of Reward: 2.002. Training.
# [INFO] Huggy. Step: 1300000. Time Elapsed: 1512.417 s. Mean Reward: 3.730. Std of Reward: 2.027. Training.
# INFO:mlagents.trainers.stats:Huggy. Step: 1300000. Time Elapsed: 1512.417 s. Mean Reward: 3.730. Std of Reward: 2.027. Training.
# [INFO] Huggy. Step: 1350000. Time Elapsed: 1569.493 s. Mean Reward: 3.706. Std of Reward: 2.193. Training.
# INFO:mlagents.trainers.stats:Huggy. Step: 1350000. Time Elapsed: 1569.493 s. Mean Reward: 3.706. Std of Reward: 2.193. Training.
# [INFO] Huggy. Step: 1400000. Time Elapsed: 1626.220 s. Mean Reward: 3.738. Std of Reward: 2.228. Training.
# INFO:mlagents.trainers.stats:Huggy. Step: 1400000. Time Elapsed: 1626.220 s. Mean Reward: 3.738. Std of Reward: 2.228. Training.
# [INFO] Exported results/Huggy/Huggy/Huggy-1399970.onnx
# INFO:mlagents.trainers.torch.model_serialization:Exported results/Huggy/Huggy/Huggy-1399970.onnx
# [INFO] Huggy. Step: 1450000. Time Elapsed: 1685.880 s. Mean Reward: 3.620. Std of Reward: 2.193. Training.
# INFO:mlagents.trainers.stats:Huggy. Step: 1450000. Time Elapsed: 1685.880 s. Mean Reward: 3.620. Std of Reward: 2.193. Training.
# [INFO] Huggy. Step: 1500000. Time Elapsed: 1742.350 s. Mean Reward: 3.580. Std of Reward: 2.122. Training.
# INFO:mlagents.trainers.stats:Huggy. Step: 1500000. Time Elapsed: 1742.350 s. Mean Reward: 3.580. Std of Reward: 2.122. Training.
# [INFO] Huggy. Step: 1550000. Time Elapsed: 1802.410 s. Mean Reward: 3.763. Std of Reward: 2.135. Training.
# INFO:mlagents.trainers.stats:Huggy. Step: 1550000. Time Elapsed: 1802.410 s. Mean Reward: 3.763. Std of Reward: 2.135. Training.
# [INFO] Huggy. Step: 1600000. Time Elapsed: 1860.133 s. Mean Reward: 3.650. Std of Reward: 2.194. Training.
# INFO:mlagents.trainers.stats:Huggy. Step: 1600000. Time Elapsed: 1860.133 s. Mean Reward: 3.650. Std of Reward: 2.194. Training.
# [INFO] Exported results/Huggy/Huggy/Huggy-1599913.onnx
# INFO:mlagents.trainers.torch.model_serialization:Exported results/Huggy/Huggy/Huggy-1599913.onnx
# [INFO] Huggy. Step: 1650000. Time Elapsed: 1918.544 s. Mean Reward: 3.662. Std of Reward: 2.076. Training.
# INFO:mlagents.trainers.stats:Huggy. Step: 1650000. Time Elapsed: 1918.544 s. Mean Reward: 3.662. Std of Reward: 2.076. Training.
# [INFO] Huggy. Step: 1700000. Time Elapsed: 1974.521 s. Mean Reward: 3.864. Std of Reward: 2.074. Training.
# INFO:mlagents.trainers.stats:Huggy. Step: 1700000. Time Elapsed: 1974.521 s. Mean Reward: 3.864. Std of Reward: 2.074. Training.
# [INFO] Huggy. Step: 1750000. Time Elapsed: 2029.212 s. Mean Reward: 3.670. Std of Reward: 2.139. Training.
# INFO:mlagents.trainers.stats:Huggy. Step: 1750000. Time Elapsed: 2029.212 s. Mean Reward: 3.670. Std of Reward: 2.139. Training.
# [INFO] Huggy. Step: 1800000. Time Elapsed: 2086.987 s. Mean Reward: 3.692. Std of Reward: 2.132. Training.
# INFO:mlagents.trainers.stats:Huggy. Step: 1800000. Time Elapsed: 2086.987 s. Mean Reward: 3.692. Std of Reward: 2.132. Training.
# [INFO] Exported results/Huggy/Huggy/Huggy-1799991.onnx
# INFO:mlagents.trainers.torch.model_serialization:Exported results/Huggy/Huggy/Huggy-1799991.onnx
# [INFO] Huggy. Step: 1850000. Time Elapsed: 2148.239 s. Mean Reward: 3.606. Std of Reward: 2.164. Training.
# INFO:mlagents.trainers.stats:Huggy. Step: 1850000. Time Elapsed: 2148.239 s. Mean Reward: 3.606. Std of Reward: 2.164. Training.
# [INFO] Huggy. Step: 1900000. Time Elapsed: 2212.248 s. Mean Reward: 3.580. Std of Reward: 2.182. Training.
# INFO:mlagents.trainers.stats:Huggy. Step: 1900000. Time Elapsed: 2212.248 s. Mean Reward: 3.580. Std of Reward: 2.182. Training.
# [INFO] Huggy. Step: 1950000. Time Elapsed: 2273.350 s. Mean Reward: 3.516. Std of Reward: 2.255. Training.
# INFO:mlagents.trainers.stats:Huggy. Step: 1950000. Time Elapsed: 2273.350 s. Mean Reward: 3.516. Std of Reward: 2.255. Training.
# [INFO] Huggy. Step: 2000000. Time Elapsed: 2331.967 s. Mean Reward: 3.354. Std of Reward: 2.424. Training.
# INFO:mlagents.trainers.stats:Huggy. Step: 2000000. Time Elapsed: 2331.967 s. Mean Reward: 3.354. Std of Reward: 2.424. Training.
# [INFO] Exported results/Huggy/Huggy/Huggy-1999975.onnx
# INFO:mlagents.trainers.torch.model_serialization:Exported results/Huggy/Huggy/Huggy-1999975.onnx
# [INFO] Exported results/Huggy/Huggy/Huggy-2000048.onnx
# INFO:mlagents.trainers.torch.model_serialization:Exported results/Huggy/Huggy/Huggy-2000048.onnx
# [INFO] Copied results/Huggy/Huggy/Huggy-2000048.onnx to results/Huggy/Huggy.onnx.
# INFO:mlagents.trainers.model_saver.torch_model_saver:Copied results/Huggy/Huggy/Huggy-2000048.onnx to results/Huggy/Huggy.onnx.

# %% [markdown]
# ## Push the agent to the 🤗 Hub
#
# - Now that we trained our agent, we’re **ready to push it to the Hub to be able to play with Huggy on your browser🔥.**

# %% [markdown]
# To be able to share your model with the community there are three more steps to follow:
#
# 1️⃣ (If it's not already done) create an account to HF ➡ https://huggingface.co/join
#
# 2️⃣ Sign in and then, you need to store your authentication token from the Hugging Face website.
# - Create a new token (https://huggingface.co/settings/tokens) **with write role**
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/create-token.jpg" alt="Create HF Token">
#
# - Copy the token
# - Run the cell below and paste the token

# %%
from huggingface_hub import notebook_login
notebook_login()
# Out:
# Token is valid.
# Your token has been saved in your configured git credential helpers (store).
# Your token has been saved to /root/.huggingface/token
# Login successful

# %% [markdown]
# If you don't want to use a Google Colab or a Jupyter Notebook, you need to use this command instead: `huggingface-cli login`

# %% [markdown]
# Then, we simply need to run `mlagents-push-to-hf`.
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/unit-bonus1/mlpush.png" alt="ml learn function" width="100%">

# %% [markdown]
# And we define 4 parameters:
#
# 1. `--run-id`: the name of the training run id.
# 2. `--local-dir`: where the agent was saved, it’s results/<run_id name>, so in my case results/First Training.
# 3. `--repo-id`: the name of the Hugging Face repo you want to create or update. It’s always <your huggingface username>/<the repo name>
# If the repo does not exist **it will be created automatically**
# 4. `--commit-message`: since HF repos are git repository you need to define a commit message.

# %%
# !mlagents-push-to-hf --run-id="HuggyTraining" --local-dir="./results/Huggy" --repo-id="ahmad1289/ppo-Huggy" --commit-message="Huggy"
# Out:
# HuggyTraining
# ahmad1289/ppo-Huggy
# This function will create a model card and upload your HuggyTraining into HuggingFace Hub. This is a work in progress: If you encounter a bug, please send open an issue
# REPO NAME:  ppo-Huggy
# ORGANIZATION:  ahmad1289
# Cloning https://huggingface.co/ahmad1289/ppo-Huggy into local empty directory.
# Upload file Huggy/Huggy-1999975.pt:   0% 3.30k/12.9M [00:00<?, ?B/s]
# Upload file Huggy/Huggy-999930.pt:   0% 3.30k/12.9M [00:00<?, ?B/s]
#
# Upload file Huggy/Huggy-399982.pt:   0% 3.30k/12.9M [00:00<?, ?B/s]
#
#
# Upload file Huggy/Huggy-599775.pt:   0% 3.30k/12.9M [00:00<?, ?B/s]
#
#
# Upload file Huggy/Huggy-599775.pt:   0% 7.30k/12.9M [00:01<54:59, 4.09kB/s]
#
# Upload file Huggy/Huggy-399982.pt:   0% 63.3k/12.9M [00:01<03:39, 61.3kB/s]
#
#
#
# Upload file Huggy/Huggy-1999975.pt:   2% 323k/12.9M [00:01<00:40, 327kB/s]
#
#
#
#
# Upload file Huggy/Huggy-799953.pt:   0% 3.30k/12.9M [00:00<?, ?B/s]
#
#
#
#
#
# Upload file Huggy/Huggy-1599913.pt:   0% 3.30k/12.9M [00:00<?, ?B/s]
#
#
#
#
#
#
# Upload file Huggy/Huggy-1199792.pt:   0% 3.30k/12.9M [00:00<?, ?B/s]
# Upload file Huggy/Huggy-999930.pt:   1% 107k/12.9M [00:01<02:06, 106kB/s]
#
#
#
#
#
# Upload file Huggy/Huggy-1599913.pt:   1% 107k/12.9M [00:01<02:05, 106kB/s]
#
#
#
#
#
#
# Upload file Huggy/Huggy-1199792.pt:   1% 107k/12.9M [00:01<02:05, 106kB/s]
#
#
# Upload file Huggy/Huggy-599775.pt:   1% 107k/12.9M [00:02<03:36, 61.8kB/s]
#
#
#
# Upload file Huggy/Huggy-1399970.pt:   1% 107k/12.9M [00:01<02:06, 106kB/s]
#
# Upload file Huggy/Huggy-1999975.pt:   6% 787k/12.9M [00:02<00:30, 413kB/s]
#
#
#
#
# Upload file Huggy/Huggy-799953.pt:   1% 111k/12.9M [00:01<02:01, 110kB/s]
# Upload file Huggy/Huggy-999930.pt:   1% 119k/12.9M [00:02<04:22, 50.9kB/s]
#
#
#
#
#
# Upload file Huggy/Huggy-1599913.pt:   6% 743k/12.9M [00:02<00:29, 426kB/s]
#
#
#
# Upload file Huggy/Huggy-1999975.pt:   7% 887k/12.9M [00:03<00:46, 271kB/s]
#
#
#
#
# Upload file Huggy/Huggy-799953.pt:   2% 283k/12.9M [00:02<01:28, 149kB/s]
# Upload file Huggy/Huggy-999930.pt:   2% 211k/12.9M [00:03<03:08, 70.6kB/s]
#
#
#
#
#
#
# Upload file Huggy/Huggy-1199792.pt:   2% 255k/12.9M [00:02<01:39, 133kB/s]
#
# Upload file Huggy/Huggy-399982.pt:   2% 311k/12.9M [00:03<02:00, 109kB/s]
#
#
# Upload file Huggy/Huggy-599775.pt:   2% 219k/12.9M [00:03<02:34, 85.7kB/s]
#
#
#
# Upload file Huggy/Huggy-1399970.pt:  10% 1.31M/12.9M [00:03<00:23, 514kB/s]
#
#
#
#
#
# Upload file Huggy/Huggy-1599913.pt:  10% 1.34M/12.9M [00:03<00:22, 526kB/s]
#
# Upload file Huggy/Huggy-399982.pt:   4% 491k/12.9M [00:04<01:33, 139kB/s]
#
#
#
#
#
# Upload file Huggy/Huggy-1599913.pt:  15% 1.95M/12.9M [00:04<00:20, 569kB/s]
#
#
#
# Upload file Huggy/Huggy-1999975.pt:   7% 915k/12.9M [00:05<01:39, 126kB/s]
#
#
#
# Upload file Huggy/Huggy-1999975.pt:   8% 0.99M/12.9M [00:06<01:45, 118kB/s]
#
#
#
# Upload file Huggy/Huggy-1999975.pt:  13% 1.64M/12.9M [00:07<00:41, 284kB/s]
#
# Upload file Huggy/Huggy-1999975.pt:  18% 2.28M/12.9M [00:08<00:27, 397kB/s]
#
# Upload file Huggy/Huggy-1999975.pt:  23% 2.94M/12.9M [00:09<00:21, 482kB/s]
#
# Upload file Huggy/Huggy-399982.pt:  12% 1.50M/12.9M [00:09<00:45, 265kB/s]
# Upload file Huggy/Huggy-999930.pt:   2% 219k/12.9M [00:09<14:19, 15.5kB/s]
# Upload file Huggy/Huggy-999930.pt:   5% 699k/12.9M [00:10<02:20, 91.2kB/s]
#
# Upload file Huggy/Huggy-399982.pt:  17% 2.16M/12.9M [00:10<00:30, 374kB/s]
#
#
#
#
#
# Upload file Huggy/Huggy-1599913.pt:  19% 2.46M/12.9M [00:09<00:47, 228kB/s]
#
#
# Upload file Huggy/Huggy-599775.pt:   2% 231k/12.9M [00:10<13:07, 16.9kB/s]
#
#
# Upload file Huggy/Huggy-599775.pt:   5% 647k/12.9M [00:11<02:50, 75.4kB/s]
#
#
#
#
#
# Upload file Huggy/Huggy-1599913.pt:  22% 2.88M/12.9M [00:10<00:39, 264kB/s]
#
#
#
# Upload file Huggy/Huggy-1399970.pt:  27% 3.50M/12.9M [00:10<00:37, 264kB/s]
#
#
#
#
#
#
# Upload file Huggy/Huggy-1199792.pt:   2% 271k/12.9M [00:10<11:37, 19.0kB/s]
#
#
#
#
#
#
# Upload file Huggy/Huggy-1199792.pt:   3% 375k/12.9M [00:11<07:07, 30.7kB/s]
#
#
#
# Upload file Huggy/Huggy-1399970.pt:  28% 3.61M/12.9M [00:11<00:41, 235kB/s]
#
#
#
# Upload file Huggy/Huggy-1399970.pt:  33% 4.24M/12.9M [00:12<00:27, 327kB/s]
#
#
#
#
#
#
# Upload file Huggy/Huggy-1199792.pt:   8% 1.00M/12.9M [00:12<01:33, 133kB/s]
#
#
#
#
#
#
# Upload file Huggy/Huggy-1199792.pt:  13% 1.64M/12.9M [00:13<00:50, 233kB/s]
#
#
#
# Upload file Huggy/Huggy-1399970.pt:  38% 4.88M/12.9M [00:13<00:20, 407kB/s]
#
#
#
#
#
#
# Upload file Huggy/Huggy-1199792.pt:  18% 2.27M/12.9M [00:14<00:34, 324kB/s]
#
#
#
# Upload file Huggy/Huggy-1399970.pt:  43% 5.51M/12.9M [00:14<00:16, 471kB/s]
#
#
#
#
#
#
# Upload file Huggy/Huggy-1199792.pt:  23% 2.90M/12.9M [00:15<00:26, 401kB/s]
#
#
#
# Upload file Huggy/Huggy-1399970.pt:  48% 6.14M/12.9M [00:15<00:13, 520kB/s]
#
#
#
#
#
#
# Upload file Huggy/Huggy-1199792.pt:  28% 3.55M/12.9M [00:16<00:20, 470kB/s]
#
#
#
# Upload file Huggy/Huggy-1399970.pt:  53% 6.79M/12.9M [00:16<00:11, 564kB/s]
#
#
#
#
#
#
# Upload file Huggy/Huggy-1199792.pt:  32% 4.18M/12.9M [00:17<00:17, 520kB/s]
#
#
#
# Upload file Huggy/Huggy-1399970.pt:  58% 7.43M/12.9M [00:17<00:09, 591kB/s]
#
#
#
#
#
#
# Upload file Huggy/Huggy-1199792.pt:  38% 4.83M/12.9M [00:18<00:14, 563kB/s]
#
#
#
# Upload file Huggy/Huggy-1999975.pt:  24% 3.12M/12.9M [00:19<00:21, 482kB/s]
#
#
#
#
# Upload file Huggy/Huggy-799953.pt:   2% 299k/12.9M [00:18<01:28, 149kB/s]
#
#
#
# Upload file Huggy/Huggy-1399970.pt:  68% 8.73M/12.9M [00:19<00:06, 636kB/s]
#
#
#
#
#
#
# Upload file Huggy/Huggy-1199792.pt:  43% 5.49M/12.9M [00:19<00:12, 598kB/s]
#
#
#
#
#
#
# Upload file Huggy/Huggy-1199792.pt:  48% 6.12M/12.9M [00:20<00:11, 618kB/s]
#
#
#
# Upload file Huggy/Huggy-1399970.pt:  73% 9.37M/12.9M [00:20<00:05, 646kB/s]
#
#
#
#
#
#
# Upload file Huggy/Huggy-1199792.pt:  53% 6.78M/12.9M [00:21<00:10, 638kB/s]
#
#
#
# Upload file Huggy/Huggy-1399970.pt:  78% 10.0M/12.9M [00:21<00:04, 658kB/s]
#
#
#
#
#
#
# Upload file Huggy/Huggy-1199792.pt:  58% 7.43M/12.9M [00:22<00:08, 650kB/s]
#
#
#
# Upload file Huggy/Huggy-1399970.pt:  83% 10.7M/12.9M [00:22<00:03, 664kB/s]
#
#
#
# Upload file Huggy/Huggy-1399970.pt:  88% 11.3M/12.9M [00:23<00:02, 674kB/s]
#
#
#
#
#
#
# Upload file Huggy/Huggy-1199792.pt:  63% 8.10M/12.9M [00:23<00:07, 665kB/s]
#
#
#
# Upload file Huggy/Huggy-1399970.pt:  93% 12.0M/12.9M [00:24<00:01, 683kB/s]
#
#
#
#
#
#
# Upload file Huggy/Huggy-1199792.pt:  68% 8.77M/12.9M [00:24<00:06, 676kB/s]
#
#
#
# Upload file Huggy/Huggy-1399970.pt:  99% 12.8M/12.9M [00:25<00:00, 724kB/s]
#
#
#
#
#
#
# Upload file Huggy/Huggy-1999975.pt:  24% 3.12M/12.9M [00:26<02:28, 68.8kB/s]
#
#
#
#
# Upload file Huggy/Huggy-799953.pt:   2% 303k/12.9M [00:25<26:55, 8.17kB/s]
#
#
#
#
# Upload file Huggy/Huggy-1999975.pt:  34% 4.35M/12.9M [00:28<00:56, 157kB/s]
#
#
#
#
# Upload file Huggy/Huggy-1999975.pt:  39% 5.02M/12.9M [00:29<00:37, 219kB/s]
#
#
#
#
# Upload file Huggy/Huggy-799953.pt:  13% 1.71M/12.9M [00:28<01:34, 124kB/s]
#
#
# Upload file Huggy/Huggy-599775.pt:   9% 1.17M/12.9M [00:29<02:42, 75.4kB/s]
# Upload file Huggy/Huggy-999930.pt:   7% 979k/12.9M [00:30<02:17, 91.2kB/s]
#
# Upload file Huggy/Huggy-399982.pt:  19% 2.51M/12.9M [00:30<00:29, 374kB/s]
#
#
#
#
#
# Upload file Huggy/Huggy-1999975.pt:  44% 5.73M/12.9M [00:30<00:25, 291kB/s]
#
#
#
#
# Upload file Huggy/Huggy-1999975.pt:  50% 6.39M/12.9M [00:31<00:19, 358kB/s]
#
#
#
#
# Upload file Huggy/Huggy-799953.pt:  24% 3.07M/12.9M [00:30<00:38, 270kB/s]
#
# Upload file Huggy/Huggy-1999975.pt:  55% 7.04M/12.9M [00:32<00:14, 419kB/s]
#
# Upload file Huggy/Huggy-399982.pt:  24% 3.05M/12.9M [00:32<01:58, 86.8kB/s]
#
# Upload file Huggy/Huggy-1999975.pt:  65% 8.31M/12.9M [00:34<00:09, 518kB/s]
#
# Upload file Huggy/Huggy-1999975.pt:  70% 8.98M/12.9M [00:35<00:07, 562kB/s]
#
# Upload file Huggy/Huggy-399982.pt:  39% 4.99M/12.9M [00:35<00:33, 245kB/s]
#
#
# Upload file Huggy/Huggy-1999975.pt:  75% 9.63M/12.9M [00:36<00:05, 594kB/s]
#
#
# Upload file Huggy/Huggy-599775.pt:  13% 1.62M/12.9M [00:36<03:44, 52.7kB/s]
#
#
# Upload file Huggy/Huggy-1999975.pt:  80% 10.3M/12.9M [00:37<00:04, 618kB/s]
#
#
#
#
#
# Upload file Huggy/Huggy-1599913.pt:  27% 3.47M/12.9M [00:36<02:56, 55.9kB/s]
# Upload file Huggy/Huggy-999930.pt:   7% 983k/12.9M [00:37<09:28, 22.0kB/s]
#
#
#
#
#
# Upload file Huggy/Huggy-1599913.pt:  30% 3.82M/12.9M [00:37<02:15, 70.3kB/s]
# Upload file Huggy/Huggy-999930.pt:  10% 1.30M/12.9M [00:38<05:30, 36.7kB/s]
#
#
#
#
#
#
# Upload file Huggy/Huggy-1199792.pt:  79% 10.1M/12.9M [00:37<00:17, 160kB/s]
#
#
#
#
#
#
# Upload file Huggy/Huggy-1199792.pt:  80% 10.2M/12.9M [00:38<00:17, 156kB/s]
# Upload file Huggy/Huggy-999930.pt:  15% 1.95M/12.9M [00:39<02:34, 74.3kB/s]
#
#
#
# Upload file Huggy/Huggy-1399970.pt: 100% 12.9M/12.9M [00:38<00:00, 724kB/s]
# Upload file Huggy/Huggy-999930.pt:  20% 2.59M/12.9M [00:40<01:29, 120kB/s]
#
#
#
#
#
#
# Upload file Huggy/Huggy-1199792.pt:  85% 10.9M/12.9M [00:39<00:09, 215kB/s]
#
#
#
#
#
#
# Upload file Huggy/Huggy-1199792.pt:  90% 11.5M/12.9M [00:40<00:05, 280kB/s]
# Upload file Huggy/Huggy-999930.pt:  25% 3.24M/12.9M [00:41<00:57, 176kB/s]
#
#
#
#
# Upload file Huggy/Huggy-799953.pt:  25% 3.19M/12.9M [00:40<01:46, 95.3kB/s]
# Upload file Huggy/Huggy-999930.pt:  30% 3.90M/12.9M [00:42<00:39, 240kB/s]
#
#
#
#
# Upload file Huggy/Huggy-799953.pt:  29% 3.71M/12.9M [00:41<01:11, 135kB/s]
#
#
#
#
# Upload file Huggy/Huggy-799953.pt:  34% 4.37M/12.9M [00:42<00:45, 197kB/s]
# Upload file Huggy/Huggy-999930.pt:  35% 4.57M/12.9M [00:43<00:28, 308kB/s]
#
# Upload file Huggy/Huggy-1999975.pt:  82% 10.6M/12.9M [00:43<00:10, 223kB/s]
#
#
#
#
#
# Upload file Huggy/Huggy-1599913.pt:  34% 4.36M/12.9M [00:42<01:50, 80.7kB/s]
#
#
#
#
#
#
# Upload file Huggy/Huggy-1199792.pt:  91% 11.7M/12.9M [00:42<00:05, 222kB/s]
#
#
# Upload file Huggy/Huggy-599775.pt:  20% 2.57M/12.9M [00:43<02:17, 78.5kB/s]
#
#
#
#
# Upload file Huggy/Huggy-799953.pt:  39% 5.03M/12.9M [00:43<00:30, 266kB/s]
# Upload file Huggy/Huggy-999930.pt:  41% 5.23M/12.9M [00:44<00:21, 377kB/s]
#
#
# Upload file Huggy/Huggy-599775.pt:  20% 2.60M/12.9M [00:44<02:23, 75.0kB/s]
#
#
#
#
#
# Upload file Huggy/Huggy-1599913.pt:  34% 4.39M/12.9M [00:43<01:54, 77.6kB/s]
#
# Upload file Huggy/Huggy-1999975.pt:  83% 10.6M/12.9M [00:44<00:11, 199kB/s]
#
#
#
#
#
#
# Upload file Huggy/Huggy-1999975.pt:  87% 11.3M/12.9M [00:45<00:06, 274kB/s]
#
#
#
#
#
#
# Upload file Huggy/Huggy-1199792.pt:  95% 12.2M/12.9M [00:44<00:02, 258kB/s]
#
#
# Upload file Huggy/Huggy-1999975.pt:  93% 11.9M/12.9M [00:46<00:02, 359kB/s]
#
#
# Upload file Huggy/Huggy-1999975.pt:  98% 12.6M/12.9M [00:47<00:00, 430kB/s]
#
#
# Upload file Huggy/Huggy-599775.pt:  26% 3.39M/12.9M [00:47<01:00, 165kB/s]
#
#
#
#
#
# Upload file Huggy/Huggy-1599913.pt:  36% 4.58M/12.9M [00:46<01:56, 74.6kB/s]
#
#
#
#
#
# Upload file Huggy/Huggy-1599913.pt:  38% 4.93M/12.9M [00:47<01:21, 103kB/s]
#
#
# Upload file Huggy/Huggy-599775.pt:  31% 4.04M/12.9M [00:48<00:36, 256kB/s]
#
#
#
#
#
# Upload file Huggy/Huggy-1599913.pt:  43% 5.60M/12.9M [00:48<00:44, 173kB/s]
#
#
# Upload file Huggy/Huggy-599775.pt:  37% 4.71M/12.9M [00:49<00:24, 345kB/s]
#
#
#
#
#
# Upload file Huggy/Huggy-1599913.pt:  48% 6.25M/12.9M [00:49<00:28, 246kB/s]
#
#
# Upload file Huggy/Huggy-599775.pt:  42% 5.35M/12.9M [00:50<00:18, 419kB/s]
#
#
# Upload file Huggy/Huggy-599775.pt:  47% 6.00M/12.9M [00:51<00:15, 480kB/s]
#
#
#
#
#
# Upload file Huggy/Huggy-1599913.pt:  53% 6.89M/12.9M [00:50<00:19, 320kB/s]
#
#
# Upload file Huggy/Huggy-599775.pt:  52% 6.66M/12.9M [00:52<00:12, 534kB/s]
#
#
#
#
#
# Upload file Huggy/Huggy-1599913.pt:  59% 7.55M/12.9M [00:51<00:14, 393kB/s]
#
# Upload file Huggy/Huggy-399982.pt:  42% 5.35M/12.9M [00:52<02:08, 61.4kB/s]
# Upload file Huggy/Huggy-999930.pt:  41% 5.34M/12.9M [00:52<00:58, 134kB/s]
#
#
#
#
# Upload file Huggy/Huggy-799953.pt:  43% 5.56M/12.9M [00:51<00:52, 145kB/s]
#
#
#
#
#
# Upload file Huggy/Huggy-1599913.pt:  63% 8.15M/12.9M [00:52<00:11, 445kB/s]
#
# Upload file Huggy/Huggy-399982.pt:  42% 5.41M/12.9M [00:53<02:09, 60.7kB/s]
# Upload file Huggy/Huggy-999930.pt:  42% 5.39M/12.9M [00:53<01:02, 126kB/s]
#
#
#
#
# Upload file Huggy/Huggy-799953.pt:  44% 5.61M/12.9M [00:52<00:55, 137kB/s]
#
#
# Upload file Huggy/Huggy-599775.pt:  56% 7.27M/12.9M [00:53<00:10, 564kB/s]
# Upload file Huggy/Huggy-999930.pt:  47% 6.04M/12.9M [00:54<00:36, 198kB/s]
#
#
#
#
# Upload file Huggy/Huggy-799953.pt:  45% 5.85M/12.9M [00:53<00:48, 151kB/s]
#
#
#
#
# Upload file Huggy/Huggy-799953.pt:  51% 6.53M/12.9M [00:54<00:28, 234kB/s]
# Upload file Huggy/Huggy-999930.pt:  52% 6.71M/12.9M [00:55<00:23, 279kB/s]
#
#
# Upload file Huggy/Huggy-599775.pt:  59% 7.57M/12.9M [00:55<00:14, 386kB/s]
#
#
#
#
# Upload file Huggy/Huggy-799953.pt:  56% 7.18M/12.9M [00:55<00:19, 313kB/s]
#
#
# Upload file Huggy/Huggy-599775.pt:  59% 7.61M/12.9M [00:56<00:18, 306kB/s]
#
#
# Upload file Huggy/Huggy-599775.pt:  64% 8.21M/12.9M [00:57<00:12, 386kB/s]
#
#
#
#
# Upload file Huggy/Huggy-799953.pt:  61% 7.82M/12.9M [00:56<00:13, 385kB/s]
#
#
# Upload file Huggy/Huggy-599775.pt:  69% 8.86M/12.9M [00:58<00:09, 466kB/s]
#
#
#
#
# Upload file Huggy/Huggy-799953.pt:  66% 8.48M/12.9M [00:57<00:10, 452kB/s]
#
#
#
#
# Upload file Huggy/Huggy-799953.pt:  71% 9.12M/12.9M [00:58<00:07, 506kB/s]
#
#
# Upload file Huggy/Huggy-1999975.pt: 100% 12.9M/12.9M [01:00<00:00, 430kB/s]
#
#
#
#
#
#
# Upload file Huggy/Huggy-1199792.pt: 100% 12.9M/12.9M [00:58<00:00, 258kB/s]
#
#
#
#
# Upload file Huggy/Huggy-799953.pt:  76% 9.78M/12.9M [00:59<00:05, 553kB/s]
#
#
# Upload file Huggy/Huggy-599775.pt:  79% 10.2M/12.9M [01:00<00:04, 571kB/s]
#
#
#
#
# Upload file Huggy/Huggy-799953.pt:  81% 10.4M/12.9M [01:00<00:04, 580kB/s]
#
#
# Upload file Huggy/Huggy-599775.pt:  84% 10.8M/12.9M [01:01<00:03, 595kB/s]
#
# Upload file Huggy/Huggy-399982.pt:  44% 5.62M/12.9M [01:01<02:51, 44.4kB/s]
#
#
# Upload file Huggy/Huggy-599775.pt:  89% 11.4M/12.9M [01:02<00:02, 613kB/s]
#
# Upload file Huggy/Huggy-399982.pt:  45% 5.74M/12.9M [01:02<02:26, 51.0kB/s]
#
# Upload file Huggy/Huggy-399982.pt:  50% 6.38M/12.9M [01:03<00:58, 116kB/s]
#
#
# Upload file Huggy/Huggy-599775.pt:  94% 12.1M/12.9M [01:03<00:01, 632kB/s]
#
#
#
#
#
# Upload file Huggy/Huggy-1599913.pt:  67% 8.59M/12.9M [01:02<00:31, 143kB/s]
#
#
#
#
#
# Upload file Huggy/Huggy-1599913.pt:  71% 9.21M/12.9M [01:03<00:20, 191kB/s]
#
#
# Upload file Huggy/Huggy-599775.pt:  99% 12.7M/12.9M [01:04<00:00, 645kB/s]
#
#
#
#
# Upload file Huggy/Huggy-799953.pt:  85% 10.9M/12.9M [01:03<00:05, 365kB/s]
#
#
#
#
#
# Upload file Huggy/Huggy-1599913.pt:  77% 9.86M/12.9M [01:04<00:12, 252kB/s]
#
#
#
#
# Upload file Huggy/Huggy-799953.pt:  89% 11.4M/12.9M [01:04<00:03, 395kB/s]
#
#
#
#
# Upload file Huggy/Huggy-799953.pt:  94% 12.1M/12.9M [01:05<00:01, 459kB/s]
#
#
#
#
#
# Upload file Huggy/Huggy-1599913.pt:  82% 10.5M/12.9M [01:05<00:07, 316kB/s]
# Upload file Huggy/Huggy-999930.pt:  57% 7.37M/12.9M [01:06<00:46, 124kB/s]
#
#
#
#
# Upload file Huggy/Huggy-799953.pt:  99% 12.7M/12.9M [01:06<00:00, 514kB/s]
# Upload file Huggy/Huggy-999930.pt:  59% 7.55M/12.9M [01:07<00:43, 130kB/s]
#
# Upload file Huggy/Huggy-399982.pt:  50% 6.41M/12.9M [01:07<01:29, 75.6kB/s]
# Upload file Huggy/Huggy-999930.pt:  64% 8.18M/12.9M [01:08<00:26, 188kB/s]
#
# Upload file Huggy/Huggy-399982.pt:  53% 6.88M/12.9M [01:08<00:50, 124kB/s]
#
#
#
#
#
# Upload file Huggy/Huggy-1599913.pt:  85% 11.0M/12.9M [01:07<00:06, 296kB/s]
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-1799991.pt:   0% 3.30k/12.9M [00:00<?, ?B/s]
#
#
#
#
#
# Upload file Huggy/Huggy-1599913.pt:  86% 11.1M/12.9M [01:08<00:07, 256kB/s]
# Upload file Huggy/Huggy-999930.pt:  68% 8.82M/12.9M [01:09<00:16, 251kB/s]
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-1799991.pt:   1% 71.3k/12.9M [00:01<03:13, 69.6kB/s]
#
#
#
#
#
# Upload file Huggy/Huggy-1599913.pt:  92% 11.8M/12.9M [01:09<00:02, 369kB/s]
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-1799991.pt:   7% 867k/12.9M [00:02<00:24, 507kB/s]
#
#
#
#
#
# Upload file Huggy/Huggy-1599913.pt:  97% 12.5M/12.9M [01:10<00:00, 438kB/s]
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-1799991.pt:  12% 1.50M/12.9M [00:03<00:20, 586kB/s]
#
# Upload file Huggy/Huggy-399982.pt:  58% 7.46M/12.9M [01:11<00:37, 150kB/s]
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-1799991.pt:  17% 2.14M/12.9M [00:04<00:18, 619kB/s]
#
# Upload file Huggy/Huggy-399982.pt:  62% 7.99M/12.9M [01:12<00:24, 206kB/s]
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-1799991.pt:  22% 2.79M/12.9M [00:05<00:16, 642kB/s]
#
# Upload file Huggy/Huggy-399982.pt:  67% 8.64M/12.9M [01:13<00:15, 284kB/s]
#
# Upload file Huggy/Huggy-399982.pt:  72% 9.32M/12.9M [01:14<00:10, 364kB/s]
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-2000048.pt:   0% 0.00/12.9M [00:00<?, ?B/s]
#
#
#
#
#
# Upload file Huggy/Huggy-1599913.pt:  98% 12.6M/12.9M [01:13<00:01, 243kB/s]
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-1799991.pt:  27% 3.47M/12.9M [00:06<00:14, 665kB/s]
# Upload file Huggy/Huggy-999930.pt:  69% 8.87M/12.9M [01:14<00:31, 134kB/s]
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-1799991.pt:  32% 4.08M/12.9M [00:07<00:14, 658kB/s]
#
# Upload file Huggy/Huggy-399982.pt:  77% 9.94M/12.9M [01:15<00:07, 425kB/s]
# Upload file Huggy/Huggy-999930.pt:  70% 9.01M/12.9M [01:15<00:30, 135kB/s]
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-1799991.pt:  37% 4.73M/12.9M [00:08<00:12, 664kB/s]
# Upload file Huggy/Huggy-999930.pt:  71% 9.14M/12.9M [01:16<00:29, 135kB/s]
# Upload file Huggy/Huggy-999930.pt:  76% 9.77M/12.9M [01:17<00:14, 228kB/s]
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-1799991.pt:  42% 5.37M/12.9M [00:09<00:11, 665kB/s]
# Upload file Huggy/Huggy-999930.pt:  81% 10.4M/12.9M [01:18<00:08, 318kB/s]
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-1799991.pt:  47% 6.01M/12.9M [00:10<00:10, 669kB/s]
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-1799991.pt:  52% 6.66M/12.9M [00:11<00:09, 670kB/s]
# Upload file Huggy/Huggy-999930.pt:  86% 11.1M/12.9M [01:19<00:04, 397kB/s]
#
#
# Upload file Huggy/Huggy-599775.pt: 100% 12.9M/12.9M [01:20<00:00, 645kB/s]
#
#
#
#
# Upload file Huggy/Huggy-799953.pt: 100% 12.9M/12.9M [01:18<00:00, 514kB/s]
# Upload file Huggy/Huggy-999930.pt:  91% 11.7M/12.9M [01:20<00:02, 467kB/s]
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-1799991.pt:  57% 7.32M/12.9M [00:12<00:08, 676kB/s]
#
# Upload file Huggy/Huggy-399982.pt:  81% 10.4M/12.9M [01:20<00:10, 233kB/s]
#
# Upload file Huggy/Huggy-399982.pt:  84% 10.9M/12.9M [01:21<00:07, 266kB/s]
# Upload file Huggy/Huggy-999930.pt:  96% 12.4M/12.9M [01:21<00:01, 522kB/s]
#
#
#
#
#
# Upload file Huggy/Huggy-1599913.pt: 100% 12.9M/12.9M [01:20<00:00, 117kB/s]
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-199674.pt:   0% 3.30k/12.9M [00:00<?, ?B/s]
#
#
#
#
#
#
#
#
#
#
# Upload file Huggy.onnx:   0% 3.30k/2.17M [00:00<?, ?B/s]
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-1799991.pt:  58% 7.53M/12.9M [00:13<00:10, 539kB/s]
#
# Upload file Huggy/Huggy-399982.pt:  90% 11.5M/12.9M [01:22<00:04, 339kB/s]
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-199674.pt:   0% 23.3k/12.9M [00:01<10:59, 20.4kB/s]
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-1799991.pt:  59% 7.59M/12.9M [00:14<00:14, 394kB/s]
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-1799991.pt:  63% 8.11M/12.9M [00:15<00:11, 441kB/s]
#
# Upload file Huggy/Huggy-399982.pt:  95% 12.2M/12.9M [01:23<00:01, 409kB/s]
#
# Upload file Huggy/Huggy-399982.pt: 100% 12.8M/12.9M [01:24<00:00, 468kB/s]
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-1799991.pt:  68% 8.76M/12.9M [00:16<00:08, 514kB/s]
#
#
#
#
#
#
#
#
#
#
# Upload file Huggy.onnx:   5% 107k/2.17M [00:03<01:00, 35.4kB/s]
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-199674.pt:   1% 107k/12.9M [00:03<06:01, 37.1kB/s]
#
#
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-1999975.onnx:   0% 3.30k/2.17M [00:00<?, ?B/s]
#
#
#
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-199674.onnx:   0% 3.30k/2.17M [00:00<?, ?B/s]
#
#
#
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-199674.onnx:  23% 519k/2.17M [00:01<00:03, 527kB/s]
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-1799991.pt:  73% 9.39M/12.9M [00:17<00:06, 557kB/s]
#
#
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-1999975.onnx:  13% 279k/2.17M [00:01<00:07, 282kB/s]
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-199674.pt:   3% 411k/12.9M [00:04<01:39, 132kB/s]
#
#
#
#
#
#
#
#
#
#
# Upload file Huggy.onnx:  22% 491k/2.17M [00:04<00:11, 150kB/s]
#
#
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-1999975.onnx:  36% 795k/2.17M [00:02<00:03, 426kB/s]
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-1799991.pt:  78% 10.0M/12.9M [00:18<00:05, 586kB/s]
#
#
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-1999975.onnx:  66% 1.42M/2.17M [00:03<00:01, 539kB/s]
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-1799991.pt:  83% 10.7M/12.9M [00:19<00:03, 613kB/s]
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-199674.pt:   4% 471k/12.9M [00:06<02:39, 81.4kB/s]
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-199674.pt:   5% 687k/12.9M [00:07<01:48, 118kB/s]
#
#
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-1999975.onnx:  96% 2.08M/2.17M [00:04<00:00, 599kB/s]
#
#
#
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-199674.onnx:  37% 827k/2.17M [00:04<00:07, 185kB/s]
#
#
#
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-199674.onnx:  63% 1.37M/2.17M [00:05<00:02, 298kB/s]
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-199674.pt:  10% 1.33M/12.9M [00:08<00:44, 274kB/s]
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-1799991.pt:  86% 11.1M/12.9M [00:21<00:04, 437kB/s]
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-199674.pt:  15% 1.98M/12.9M [00:09<00:29, 387kB/s]
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-1799991.pt:  88% 11.4M/12.9M [00:22<00:03, 400kB/s]
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-199674.pt:  20% 2.61M/12.9M [00:10<00:23, 466kB/s]
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-1799991.pt:  93% 12.0M/12.9M [00:23<00:01, 468kB/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-399982.onnx:   0% 3.30k/2.17M [00:00<?, ?B/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-1799991.onnx:   0% 3.30k/2.17M [00:00<?, ?B/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-599775.onnx:   0% 3.30k/2.17M [00:00<?, ?B/s]
#
#
#
#
#
#
#
#
#
#
# Upload file Huggy.onnx:  28% 611k/2.17M [00:10<00:29, 55.0kB/s]
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-1799991.pt:  98% 12.6M/12.9M [00:24<00:00, 521kB/s]
#
#
#
#
#
#
#
#
#
#
# Upload file Huggy.onnx:  41% 907k/2.17M [00:11<00:14, 91.8kB/s]
#
#
#
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-199674.onnx:  81% 1.75M/2.17M [00:08<00:02, 208kB/s]
#
#
#
#
#
#
#
#
#
#
# Upload file Huggy.onnx:  69% 1.50M/2.17M [00:12<00:03, 189kB/s]
#
#
#
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-199674.onnx:  99% 2.14M/2.17M [00:09<00:00, 248kB/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-1599913.onnx:   0% 3.30k/2.17M [00:00<?, ?B/s]
#
#
#
#
#
#
#
#
#
#
# Upload file Huggy.onnx:  98% 2.11M/2.17M [00:13<00:00, 279kB/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-1599913.onnx:  27% 591k/2.17M [00:01<00:02, 601kB/s]
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-199674.pt:  21% 2.73M/12.9M [00:13<00:46, 231kB/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-1599913.onnx:  54% 1.18M/2.17M [00:02<00:01, 618kB/s]
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-199674.pt:  25% 3.27M/12.9M [00:14<00:33, 302kB/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-1599913.onnx:  82% 1.78M/2.17M [00:03<00:00, 625kB/s]
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-199674.pt:  30% 3.88M/12.9M [00:15<00:24, 378kB/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-799953.onnx:   0% 3.30k/2.17M [00:00<?, ?B/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-799953.onnx:  10% 223k/2.17M [00:01<00:09, 225kB/s]
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-199674.pt:  35% 4.48M/12.9M [00:16<00:20, 440kB/s]
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-199674.pt:  39% 5.08M/12.9M [00:17<00:16, 488kB/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-799953.onnx:  38% 839k/2.17M [00:02<00:03, 463kB/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-799953.onnx:  65% 1.41M/2.17M [00:03<00:01, 534kB/s]
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-199674.pt:  44% 5.67M/12.9M [00:18<00:14, 524kB/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-599775.onnx:   5% 107k/2.17M [00:08<02:42, 13.3kB/s]
#
#
#
#
#
# Upload file Huggy/Huggy-1599913.pt: 100% 12.9M/12.9M [01:38<00:00, 117kB/s]
#
# Upload file Huggy/Huggy-399982.pt: 100% 12.9M/12.9M [01:40<00:00, 468kB/s]
#
#
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-1999975.onnx: 100% 2.17M/2.17M [00:15<00:00, 599kB/s]
# Upload file Huggy/Huggy-999930.pt: 100% 12.9M/12.9M [01:40<00:00, 522kB/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-799953.onnx:  93% 2.01M/2.17M [00:04<00:00, 571kB/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-599775.onnx:  13% 279k/2.17M [00:09<00:52, 37.9kB/s]
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-199674.pt:  48% 6.12M/12.9M [00:19<00:13, 509kB/s]
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-199674.pt:  51% 6.55M/12.9M [00:20<00:13, 493kB/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-599775.onnx:  40% 887k/2.17M [00:10<00:09, 142kB/s]
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-199674.pt:  55% 7.14M/12.9M [00:21<00:11, 528kB/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-599775.onnx:  67% 1.45M/2.17M [00:11<00:03, 237kB/s]
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-199674.pt:  60% 7.73M/12.9M [00:22<00:09, 555kB/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-599775.onnx:  95% 2.05M/2.17M [00:12<00:00, 324kB/s]
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-199674.pt:  68% 8.74M/12.9M [00:23<00:06, 701kB/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-199674.pt:  73% 9.39M/12.9M [00:24<00:05, 697kB/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-199674.pt:  77% 9.98M/12.9M [00:25<00:04, 671kB/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-199674.pt:  78% 10.1M/12.9M [00:26<00:05, 495kB/s]
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-199674.pt:  80% 10.3M/12.9M [00:27<00:06, 429kB/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-199674.pt:  86% 11.0M/12.9M [00:28<00:03, 529kB/s]
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-1799991.pt: 100% 12.9M/12.9M [00:41<00:00, 521kB/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-1599913.onnx: 100% 2.17M/2.17M [00:16<00:00, 625kB/s]
#
#
#
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-199674.onnx: 100% 2.17M/2.17M [00:25<00:00, 248kB/s]
#
#
#
#
#
#
#
#
#
#
# Upload file Huggy.onnx: 100% 2.17M/2.17M [00:28<00:00, 279kB/s]
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-199674.pt:  91% 11.7M/12.9M [00:29<00:02, 567kB/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-199674.pt:  96% 12.3M/12.9M [00:30<00:01, 594kB/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-1799991.onnx:   0% 3.30k/2.17M [00:23<14:20, 2.64kB/s]
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-2000048.pt:   0% 3.30k/12.9M [00:40<44:31:02, 84.2B/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-399982.onnx:   0% 3.30k/2.17M [00:23<12:38, 2.99kB/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-399982.onnx:  17% 367k/2.17M [00:24<01:17, 24.6kB/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-1799991.onnx:  16% 363k/2.17M [00:24<01:19, 24.0kB/s]
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-2000048.pt:   3% 359k/12.9M [00:41<17:20, 12.6kB/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-1799991.onnx:  46% 1.00M/2.17M [00:25<00:16, 74.2kB/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-399982.onnx:  47% 1.01M/2.17M [00:25<00:16, 75.0kB/s]
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-2000048.pt:   4% 543k/12.9M [00:42<10:20, 20.9kB/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-1799991.onnx:  76% 1.64M/2.17M [00:26<00:04, 134kB/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-399982.onnx:  76% 1.65M/2.17M [00:26<00:04, 134kB/s]
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-2000048.pt:   4% 571k/12.9M [00:43<10:05, 21.3kB/s]
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-2000048.pt:   6% 743k/12.9M [00:44<06:14, 34.1kB/s]
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-2000048.pt:  15% 1.92M/12.9M [00:45<01:10, 162kB/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-599775.onnx: 100% 2.17M/2.17M [00:28<00:00, 324kB/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-799953.onnx: 100% 2.17M/2.17M [00:23<00:00, 571kB/s]
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-2000048.pt:  24% 3.10M/12.9M [00:46<00:33, 302kB/s]
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-2000048.pt:  33% 4.28M/12.9M [00:47<00:20, 450kB/s]
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-2000048.pt:  43% 5.49M/12.9M [00:48<00:12, 599kB/s]
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-2000048.pt:  52% 6.69M/12.9M [00:49<00:08, 736kB/s]
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-2000048.pt:  61% 7.89M/12.9M [00:50<00:06, 854kB/s]
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-2000048.pt:  71% 9.11M/12.9M [00:51<00:04, 959kB/s]
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-2000048.pt:  80% 10.3M/12.9M [00:52<00:02, 1.04MB/s]
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-2000048.pt:  90% 11.6M/12.9M [00:53<00:01, 1.11MB/s]
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-2000048.pt:  99% 12.8M/12.9M [00:54<00:00, 1.16MB/s]
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-199674.pt: 100% 12.9M/12.9M [00:48<00:00, 594kB/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-399982.onnx: 100% 2.17M/2.17M [00:38<00:00, 134kB/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-1799991.onnx: 100% 2.17M/2.17M [00:38<00:00, 134kB/s]remote: Scanning LFS files for validity, may be slow...
# remote: LFS file scan complete.
# To https://huggingface.co/ahmad1289/ppo-Huggy
#    d3dc3a0..a0eb94d  main -> main
#
# WARNING:huggingface_hub.repository:remote: Scanning LFS files for validity, may be slow...
# remote: LFS file scan complete.
# To https://huggingface.co/ahmad1289/ppo-Huggy
#    d3dc3a0..a0eb94d  main -> main
#
# Upload file Huggy/Huggy-1999975.pt: 100% 12.9M/12.9M [02:11<00:00, 19.3kB/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-1999975.pt: 100% 12.9M/12.9M [02:11<00:00, 103kB/s]
#
# Upload file Huggy/Huggy-999930.pt: 100% 12.9M/12.9M [02:11<00:00, 37.2kB/s]
# Upload file Huggy/Huggy-999930.pt: 100% 12.9M/12.9M [02:11<00:00, 103kB/s]
#
#
# Upload file Huggy/Huggy-399982.pt: 100% 12.9M/12.9M [02:11<00:00, 30.2kB/s]
#
# Upload file Huggy/Huggy-399982.pt: 100% 12.9M/12.9M [02:11<00:00, 103kB/s]
#
#
#
# Upload file Huggy/Huggy-599775.pt: 100% 12.9M/12.9M [02:11<00:00, 24.5kB/s]
#
#
# Upload file Huggy/Huggy-599775.pt: 100% 12.9M/12.9M [02:11<00:00, 103kB/s]
#
#
#
#
# Upload file Huggy/Huggy-1399970.pt: 100% 12.9M/12.9M [02:10<00:00, 16.6kB/s]
#
#
#
# Upload file Huggy/Huggy-1399970.pt: 100% 12.9M/12.9M [02:10<00:00, 104kB/s]
#
#
#
#
#
# Upload file Huggy/Huggy-799953.pt: 100% 12.9M/12.9M [02:10<00:00, 24.8kB/s]
#
#
#
#
# Upload file Huggy/Huggy-799953.pt: 100% 12.9M/12.9M [02:10<00:00, 104kB/s]
#
#
#
#
#
#
# Upload file Huggy/Huggy-1599913.pt: 100% 12.9M/12.9M [02:10<00:00, 16.3kB/s]
#
#
#
#
#
# Upload file Huggy/Huggy-1599913.pt: 100% 12.9M/12.9M [02:10<00:00, 104kB/s]
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-1199792.pt: 100% 12.9M/12.9M [02:10<00:00, 17.9kB/s]
#
#
#
#
#
#
# Upload file Huggy/Huggy-1199792.pt: 100% 12.9M/12.9M [02:10<00:00, 104kB/s]
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-1799991.pt: 100% 12.9M/12.9M [01:03<00:00, 38.1kB/s]
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-1799991.pt: 100% 12.9M/12.9M [01:03<00:00, 214kB/s]
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-2000048.pt: 100% 12.9M/12.9M [00:57<00:00, 236kB/s]
#
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-199674.pt: 100% 12.9M/12.9M [00:50<00:00, 89.3kB/s]
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-199674.pt: 100% 12.9M/12.9M [00:50<00:00, 269kB/s]
#
#
#
#
#
#
#
#
#
#
#
# Upload file Huggy.onnx: 100% 2.17M/2.17M [00:50<00:00, 25.4kB/s]
#
#
#
#
#
#
#
#
#
#
# Upload file Huggy.onnx: 100% 2.17M/2.17M [00:50<00:00, 45.2kB/s]
#
#
#
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-1999975.onnx: 100% 2.17M/2.17M [00:47<00:00, 25.7kB/s]
#
#
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-1999975.onnx: 100% 2.17M/2.17M [00:47<00:00, 48.1kB/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-199674.onnx: 100% 2.17M/2.17M [00:47<00:00, 21.1kB/s]
#
#
#
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-199674.onnx: 100% 2.17M/2.17M [00:47<00:00, 48.1kB/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-399982.onnx: 100% 2.17M/2.17M [00:40<00:00, 70.6kB/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-399982.onnx: 100% 2.17M/2.17M [00:40<00:00, 56.6kB/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-1799991.onnx: 100% 2.17M/2.17M [00:40<00:00, 70.7kB/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-1799991.onnx: 100% 2.17M/2.17M [00:40<00:00, 56.6kB/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-599775.onnx: 100% 2.17M/2.17M [00:40<00:00, 36.4kB/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-599775.onnx: 100% 2.17M/2.17M [00:40<00:00, 56.6kB/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-1599913.onnx: 100% 2.17M/2.17M [00:38<00:00, 37.1kB/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-1599913.onnx: 100% 2.17M/2.17M [00:38<00:00, 59.5kB/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-799953.onnx: 100% 2.17M/2.17M [00:35<00:00, 35.8kB/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-799953.onnx: 100% 2.17M/2.17M [00:35<00:00, 64.6kB/s]
# Upload file Huggy/Huggy-1399970.onnx: 100% 2.17M/2.17M [00:27<00:00, 83.8kB/s]
#
# Upload file Huggy/Huggy-999930.onnx: 100% 2.17M/2.17M [00:27<00:00, 83.8kB/s]
#
#
# Upload file Huggy/Huggy-1199792.onnx: 100% 2.17M/2.17M [00:27<00:00, 50.9kB/s]
#
# Upload file Huggy/Huggy-1199792.onnx: 100% 2.17M/2.17M [00:27<00:00, 83.8kB/s]
#
#
#
# Upload file Huggy/events.out.tfevents.1673455445.2d7abd8619f7.4105.0: 100% 360k/360k [00:24<00:00, 12.7kB/s]
#
#
# Upload file Huggy/events.out.tfevents.1673455445.2d7abd8619f7.4105.0: 100% 360k/360k [00:24<00:00, 15.2kB/s]
#
#  Your model is pushed to the hub. You can view your model here: https://huggingface.co/ahmad1289/ppo-Huggy

# %% [markdown]
# Else, if everything worked you should have this at the end of the process:
#
#
#
# ```
# Your model is pushed to the hub. You can view your model here:  https://huggingface.co/ahmad1289/ppo-Huggy
# ```
#
# It’s the link to your model repository. The repository contains a model card that explains how to use the model, your Tensorboard logs and your config file. **What’s awesome is that it’s a git repository, which means you can have different commits, update your repository with a new push, open Pull Requests, etc.**
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/unit-bonus1/modelcard.png" alt="ml learn function" width="100%">

# %% [markdown]
# But now comes the best: **being able to play with Huggy online 👀.**

# %% [markdown]
# ## Play with your Huggy 🐕
#
# This step is the simplest:
#
# - Open the game Huggy in your browser: https://singularite.itch.io/huggy
#
# - Click on Play with my Huggy model
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/unit-bonus1/load-huggy.jpg" alt="load-huggy" width="100%">

# %% [markdown]
# 1. In step 1, choose your model repository which is the model id (in my case ThomasSimonini/ppo-Huggy).
#
# 2. In step 2, **choose what model you want to replay**:
#   - I have multiple ones, since we saved a model every 500000 timesteps.
#   - But since I want the more recent, I choose `Huggy.onnx`
#
# 👉 What’s nice **is to try with different models steps to see the improvement of the agent.**

# %% [markdown]
# Congrats on finishing this bonus unit!
#
# You can now sit and enjoy playing with your Huggy 🐶. And don't **forget to spread the love by sharing Huggy with your friends 🤗**. And if you share about it on social media, **please tag us @huggingface and me @simoninithomas**
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/unit-bonus1/huggy-cover.jpeg" alt="Huggy cover" width="100%">
#
#
# ## Keep Learning, Stay  awesome 🤗
